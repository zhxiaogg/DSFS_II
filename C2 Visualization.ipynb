# %% [markdown]
# # Chapter 3, Data Visualization

# %% [markdown]
# ## Line Charts

# %%
from matplotlib import pyplot as plt

years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title('Nominal GDP')
plt.ylabel('Billions of $')
plt.show()

# %%
variance = [2 ** i for i in [0, 1, 2, 3, 4, 5, 6, 7, 8]]
bias_squared = list(reversed(variance))
total_error = [x + y for (x, y) in zip(variance, bias_squared)]
xs = list(range(len(variance)))

plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias_squared, 'r-.', label='bias^2')
plt.plot(xs, total_error, 'b:', label='total error')

plt.legend(loc = 9)
plt.xlabel('model complexity')
plt.xticks([])
plt.title('The Bias-Variance Tradeoff')
plt.show()

# %% [markdown]
# ## Bar Charts

# %%
from collections import Counter
grades = [83, 95, 91, 87, 0, 85, 82, 100, 67, 73, 77, 0]

histogram = Counter(min(grade // 10 * 10, 90) for grade in grades)

plt.bar([x + 5 for x in histogram.keys()], histogram.values(),10, edgecolor = (0,0,0))
plt.xticks([10 * i for i in range(11)])
plt.show()

# %% [markdown]
# ## Image

# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os

plt.rcParams['figure.figsize'] = [16, 8]


A = imread(os.path.join('DATA','dog.jpg'))
X = np.mean(A, -1); # Convert RGB to grayscale

img = plt.imshow(X)
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Scatter Charts

# %%
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

for label, num_friends, num_minutes in zip(labels, friends, minutes):
    plt.annotate(label, xy=(num_friends, num_minutes), xytext=(5, -5), textcoords='offset points')
    
plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")
plt.show()
